# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkapoor279/CS50-PYTHON-COURSE/blob/main/Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# DATAFRAME
#
# CREATON OF
# 2D STRUCTURE OF DATA CONSISITING OF ROWS AND COLUMNS. A SINGLE COL OR A ROW IN A DATAFRAME IS CALLED A SERIES.

# %%
#using lists
student_data =[
    [100,80,10],
    [90,70,4],
    [80,50,9],
    [50,23,13]
]

pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        4
# 2   80     50        9
# 3   50     23       13

# %%
#using dictionaries

student_dict={
    'name':['Palak','Yash','Aditya','Medha','Nitin','Ayush'],
    'iq':[100,90,80,50,0,0],
    'marks':[100,90,80,50,0,0],
    'package':[10,4,9,13,0,0]
}

students =pd.DataFrame(student_dict)
students.set_index('name',inplace = True)
students
# Out:
#          iq  marks  package
# name
# Palak   100    100       10
# Yash     90     90        4
# Aditya   80     80        9
# Medha    50     50       13
# Nitin     0      0        0
# Ayush     0      0        0

# %%
movies=pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#using read csv
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies.shape
# Out:
# (1629, 18)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#dtypes - every column(series) will have its own datatype
movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
#columns
movies.columns #all the column name present in the movies dataset
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
students.columns
# Out:
# Index(['iq', 'marks', 'package'], dtype='object')

# %%
#values - 2d numpy array
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
students.values
# Out:
# array([[100, 100,  10],
#        [ 90,  90,   4],
#        [ 80,  80,   9],
#        [ 50,  50,  13],
#        [  0,   0,   0],
#        [  0,   0,   0]])

# %%
#head and tail
movies.head(57)
# Out:
#                                  title_x     imdb_id  \
# 0               Uri: The Surgical Strike   tt8291224
# 1                          Battalion 609   tt9472208
# 2   The Accidental Prime Minister (film)   tt6986710
# 3                        Why Cheat India   tt8108208
# 4                        Evening Shadows   tt6028796
# 5                            Soni (film)   tt6078866
# 6                          Fraud Saiyaan   tt5013008
# 7                             Bombairiya   tt4971258
# 8       Manikarnika: The Queen of Jhansi   tt6903440
# 9                       Thackeray (film)   tt7777196
# 10                                Amavas   tt8396186
# 11                             Gully Boy   tt2395469
# 12                             Hum Chaar   tt9319812
# 13                         Total Dhamaal   tt7639372
# 14                            Sonchiriya   tt8108200
# 15                     Badla (2019 film)   tt8130968
# 16                Mard Ko Dard Nahi Hota   tt8055888
# ...

# %%
ipl.tail(500)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 450  829789     Chennai  2015-05-08     2015          43
# 451  829787      Mumbai  2015-05-07     2015          41
# 452  829761     Kolkata  2015-05-07     2015          42
# 453  829785   Bangalore  2015-05-06     2015          40
# 454  829783      Mumbai  2015-05-05     2015          39
# ..      ...         ...         ...      ...         ...
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 450          Chennai Super Kings               Mumbai Indians
# 451             Rajasthan Royals          Sunrisers Hyderabad
# 452        Kolkata Knight Riders             Delhi Daredevils
# ...

# %%
#sample - random data visualisation
ipl.sample(6)
# Out:
#           ID        City        Date   Season MatchNumber  \
# 276  1136598      Indore  2018-05-06     2018          38
# 561   598028  Dharamsala  2013-05-16     2013          67
# 926   336005      Jaipur  2008-05-04  2007/08          24
# 501   734033  Chandigarh  2014-05-23     2014          52
# 771   501201       Delhi  2011-04-10     2011           4
# 535   729311         NaN  2014-04-27     2014          17
#
#                    Team1                Team2  \
# 276     Rajasthan Royals      Kings XI Punjab
# 561      Kings XI Punjab     Delhi Daredevils
# 926     Rajasthan Royals  Chennai Super Kings
# 501      Kings XI Punjab     Rajasthan Royals
# 771     Delhi Daredevils       Mumbai Indians
# 535  Sunrisers Hyderabad  Chennai Super Kings
#
#                                             Venue           TossWinner  \
# 276                        Holkar Cricket Stadium      Kings XI Punjab
# 561  Himachal Pradesh Cricket Association Stadium     Delhi Daredevils
# ...

# %%
#info - overview of data
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#describe - gives mathematical description of the data
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull
movies.isnull().sum() #no. of missing values in each column
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#duplicated
movies.duplicated() #tells if there is any duplicate row present
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626    False
# 1627    False
# 1628    False
# Length: 1629, dtype: bool

# %%
students.duplicated()
# Out:
# name
# Palak     False
# Yash      False
# Aditya    False
# Medha     False
# Nitin     False
# Ayush      True
# dtype: bool

# %%
#rename - renames the name of column in dtaframe (not permanent)
students
# Out:
#          iq  marks  package
# name
# Palak   100    100       10
# Yash     90     90        4
# Aditya   80     80        9
# Medha    50     50       13
# Nitin     0      0        0
# Ayush     0      0        0

# %%
students.rename(columns={'marks':'percent','package':'lpa'},inplace = True) #inplace makes permanent changes int dataframe

# %%
students.rename(columns={'marks':'percent','package':'lpa'})
# Out:
#          iq  percent  lpa
# name
# Palak   100      100   10
# Yash     90       90    4
# Aditya   80       80    9
# Medha    50       50   13
# Nitin     0        0    0
# Ayush     0        0    0

# %% [markdown]
# MATH METHODS

# %%
#-> automatically sum up all the columns
movies.sum(numeric_only=True)
# Out:
# is_adult                 0.0
# year_of_release    3274720.0
# imdb_rating           9053.1
# imdb_votes         8770965.0
# dtype: float64

# %%
students.sum(axis=1) #row wise sum when axis = 1
# Out:
# name
# Palak     210
# Yash      184
# Aditya    169
# Medha     113
# Nitin       0
# Ayush       0
# dtype: int64

# %%
students.mean()
# Out:
# iq         53.333333
# percent    53.333333
# lpa         6.000000
# dtype: float64

# %%
print(students.min()) #column wise minimum values
print(students.median())
print(students.var())
# Out:
# iq         0
# percent    0
# lpa        0
# dtype: int64
# iq         65.0
# percent    65.0
# lpa         6.5
# dtype: float64
# iq         1986.666667
# percent    1986.666667
# lpa          30.000000
# dtype: float64

# %% [markdown]
# SELECTING COLUMNS FROM DATAFRAME

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#say i only want names of the movie
movies['imdb_id']
# Out:
# 0        tt8291224
# 1        tt9472208
# 2        tt6986710
# 3        tt8108208
# 4        tt6028796
#            ...
# 1624     tt0301250
# 1625     tt0298607
# 1626     tt0069204
# 1627    tt10833860
# 1628     tt2403201
# Name: imdb_id, Length: 1629, dtype: object

# %%
type(movies['imdb_id']) #single column is called series in a df
# Out:
# pandas.core.series.Series

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
#fetching multiple columns
ipl[['Venue','City','Season']]  #fancy indexing
# Out:
#                                           Venue        City   Season
# 0              Narendra Modi Stadium, Ahmedabad   Ahmedabad     2022
# 1              Narendra Modi Stadium, Ahmedabad   Ahmedabad     2022
# 2                         Eden Gardens, Kolkata     Kolkata     2022
# 3                         Eden Gardens, Kolkata     Kolkata     2022
# 4                      Wankhede Stadium, Mumbai      Mumbai     2022
# ..                                          ...         ...      ...
# 945                                Eden Gardens     Kolkata  2007/08
# 946                            Wankhede Stadium      Mumbai  2007/08
# 947                            Feroz Shah Kotla       Delhi  2007/08
# 948  Punjab Cricket Association Stadium, Mohali  Chandigarh  2007/08
# 949                       M Chinnaswamy Stadium   Bangalore  2007/08
#
# [950 rows x 3 columns]

# %%
type(ipl[['Venue','City','Season']])
# Out:
# pandas.core.frame.DataFrame

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# Fetching rows out of dataframe

# %% [markdown]
# iloc - searches using index position
#
# loc - searches using index labels

# %%
#single row
movies.iloc[0]
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
#multiple rows
movies.iloc[5:100]
# Out:
#                              title_x    imdb_id  \
# 5                        Soni (film)  tt6078866
# 6                      Fraud Saiyaan  tt5013008
# 7                         Bombairiya  tt4971258
# 8   Manikarnika: The Queen of Jhansi  tt6903440
# 9                   Thackeray (film)  tt7777196
# ..                               ...        ...
# 95                         3 Storeys  tt4552546
# 96                  Raid (2018 film)  tt7363076
# 97                            Hichki  tt6588966
# 98               Missing (2018 film)  tt7384848
# 99                          Baaghi 2  tt6843812
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# ..                                                ...
# ...

# %%
movies.iloc[0:5:2]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 2  The Accidental Prime Minister (film)  tt6986710
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
# 4                Evening Shadows                Evening Shadows         0
#
# ...

# %%
movies[5:] #5 onwards
movies[:5] #till 5
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.iloc[[0,55,44]]  #fancy indexing
# Out:
#                      title_x    imdb_id  \
# 0   Uri: The Surgical Strike  tt8291224
# 55       Pal Pal Dil Ke Paas  tt6978954
# 44      Judgementall Hai Kya  tt8108196
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 55  https://upload.wikimedia.org/wikipedia/en/thum...
# 44  https://upload.wikimedia.org/wikipedia/en/c/c8...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 55  https://en.wikipedia.org/wiki/Pal_Pal_Dil_Ke_Paas
# 44  https://en.wikipedia.org/wiki/Judgementall_Hai...
#
#                      title_y            original_title  is_adult  \
# 0   Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 55       Pal Pal Dil Ke Paas       Pal Pal Dil Ke Paas         0
# 44      Judgementall Hai Kya      Judgementall Hai Kya         0
#
#     year_of_release runtime                 genres  imdb_rating  imdb_votes  \
# ...

# %%
#loc
students
# Out:
#          iq  percent  lpa
# name
# Palak   100      100   10
# Yash     90       90    4
# Aditya   80       80    9
# Medha    50       50   13
# Nitin     0        0    0
# Ayush     0        0    0

# %%
students.loc['Yash'] #searching using index labels
# Out:
# iq         90
# percent    90
# lpa         4
# Name: Yash, dtype: int64

# %%
students.loc['Yash':'Nitin'] #in loc a:b... b is inclusive everywhere else it is exclusive
# Out:
#         iq  percent  lpa
# name
# Yash    90       90    4
# Aditya  80       80    9
# Medha   50       50   13
# Nitin    0        0    0

# %%
students.loc[['Yash','Palak']]
# Out:
#         iq  percent  lpa
# name
# Yash    90       90    4
# Palak  100      100   10

# %%
students.iloc[0:4]
# Out:
#          iq  percent  lpa
# name
# Palak   100      100   10
# Yash     90       90    4
# Aditya   80       80    9
# Medha    50       50   13

# %%
#selecting both rows and columns
#fetch three movies - only three columns
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# FILTERING A DATAFRAME

# %%
ipl.sample(10)
# Out:
#           ID          City        Date   Season MatchNumber  \
# 904   336029       Chennai  2008-05-21  2007/08          46
# 934   335997       Kolkata  2008-04-29  2007/08          16
# 391   980983     Hyderabad  2016-05-12     2016          42
# 84   1254110         Dubai  2021-10-04     2021          50
# 855   392219  Johannesburg  2009-05-10     2009          39
# 21   1304099          Pune  2022-05-07     2022          53
# 541   729299           NaN  2014-04-24     2014          11
# 590   598035        Raipur  2013-04-28     2013          39
# 199  1178431        Mumbai  2019-05-05     2019          56
# 783   419157     Bangalore  2010-04-17  2009/10          52
#
#                            Team1                        Team2  \
# 904          Chennai Super Kings  Royal Challengers Bangalore
# 934        Kolkata Knight Riders               Mumbai Indians
# 391          Sunrisers Hyderabad             Delhi Daredevils
# ...

# %%
#finding all the winners
new_df = ipl[ipl['MatchNumber']=='Final']
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how many super over finish have occured
ipl[ipl['SuperOver']=='Y'].shape[0]  #shape is used to find the number of rows and columns we did [0] to fetch row
# Out:
# 14

# %%
#how many matches has csk won in kolkata
ipl[(ipl['WinningTeam']=='Chennai Super Kings') & (ipl['City']=='Kolkata')].shape[0]
# Out:
# 5

# %%
#toss winner is match winner percentage
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
(ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#movies with rating higher than 8 and votes >1000
movies[(movies['imdb_rating']>8)&(movies['imdb_votes']>10000)].shape[0]
# Out:
# 43

# %%
#action movies with rating higher than 7.5
#m1 = movies['genres'].str.split('|').apply(lambda x: 'Action' in x)
m1 = movies['genres'].str.contains('Action')
m2 = movies['imdb_rating']>7.5
movies[m1&m2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
#write a function can return track record of 2 teams against each other

# %% [markdown]
# Adding new cols

# %%
#completely new
movies['country']='India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
#from existing rows
movies.dropna(inplace = True) #drop all missing values
movies['actors'].str.split('|').apply(lambda x : x[0] )
# Out:
# 11             Ranveer Singh
# 34              Gavie Chahal
# 37        Ayushmann Khurrana
# 87         Sidharth Malhotra
# 96                Ajay Devgn
#                 ...
# 1600             Divya Dutta
# 1601               Anant Nag
# 1607             Anil Kapoor
# 1621    Priyanshu Chatterjee
# 1623          Karisma Kapoor
# Name: actors, Length: 298, dtype: object

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
# ...

# %% [markdown]
# IMPORTANT DATAFRAME FUNCTIONS

# %%
#astype - changes dtype of a given column
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID']=ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season']=ipl['Season'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
